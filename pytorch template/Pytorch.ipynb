# %% [markdown]
# video link:
#
# https://drive.google.com/file/d/1kD9rjDo4noZn84T-oHwcOESSWPHqXpmO/view?usp=sharing

# %% [markdown]
# # Introduction to Pytorch
#
# PyTorch is a machine learning framework produced by Facebook in October 2016. It is open source, and is based on the popular Torch library. PyTorch is designed to provide good flexibility and high speeds for deep neural network implementation.
#
#
# Pytorch doc:
#
# https://pytorch.org/docs/stable/index.html

# %% [markdown]
# ![pytorch_1-1024x289.png](data:image/png;base64,...)

# %% [markdown]
# # Tensor

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
a = [i for i in range(5)]
print(a)
print(type(a))
# Out:
# [0, 1, 2, 3, 4]
# <class 'list'>

# %%
# turn list to tensor
b = torch.tensor(a,dtype=torch.float32) # dtype=torch.float32
print(b)
print(b.shape)
print(b.device)
print(b.dtype)
# Out:
# tensor([0., 1., 2., 3., 4.])
# torch.Size([5])
# cpu
# torch.float32

# %%
# bumpy array
c = np.random.normal(0,2,size=(1,5))
c
# Out:
# array([[-1.52284791, -1.78770622,  2.84852957, -2.35036292,  1.6244928 ]])

# %%
# turn array numpy to tensor
d = torch.from_numpy(c)
d
# Out:
# tensor([[-1.5228, -1.7877,  2.8485, -2.3504,  1.6245]], dtype=torch.float64)

# %%
# turn tensor to numpy
e = d.numpy()
e
# Out:
# array([[-1.52284791, -1.78770622,  2.84852957, -2.35036292,  1.6244928 ]])

# %%
# add and sub and div
d = torch.rand(1,5)
print(d)

add = torch.add(d, 20)
print(add)

sub = torch.sub(d, 0.8)
print(sub)

div = torch.div(d, 2)
print(div)
# Out:
# tensor([[0.3480, 0.0692, 0.8895, 0.6166, 0.8826]])
# tensor([[20.3480, 20.0692, 20.8895, 20.6166, 20.8826]])
# tensor([[-0.4520, -0.7308,  0.0895, -0.1834,  0.0826]])
# tensor([[0.1740, 0.0346, 0.4447, 0.3083, 0.4413]])

# %%
# slicing
d = torch.rand(3,5)
print(d)
print(d[:,2])
print(d[1,1])
# Out:
# tensor([[0.5837, 0.9788, 0.9280, 0.5438, 0.7499],
#         [0.5390, 0.6097, 0.5184, 0.2171, 0.5424],
#         [0.3099, 0.1855, 0.2043, 0.0845, 0.1678]])
# tensor([0.9280, 0.5184, 0.2043])
# tensor(0.6097)

# %%
a = torch.tensor([[1, 2],[3, 4]])
print(a)
print(a.shape)
# Out:
# tensor([[1, 2],
#         [3, 4]])
# torch.Size([2, 2])

# %%
torch.random.manual_seed(5)

# %%
a = torch.randint(3,10,(3,5))
a
# Out:
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %%
a.T
# Out:
# tensor([[4, 4, 3],
#         [8, 4, 9],
#         [5, 6, 7],
#         [6, 8, 5],
#         [9, 7, 6]])

# %%
b = torch.reshape(a, (5,3))
b
# Out:
# tensor([[4, 8, 5],
#         [6, 9, 4],
#         [4, 6, 8],
#         [7, 3, 9],
#         [7, 5, 6]])

# %%
c = torch.cat([a,a,a],dim=0)
c
# Out:
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6],
#         [4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6],
#         [4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %%
c = torch.cat([a,a,a],dim=1)
c
# Out:
# tensor([[4, 8, 5, 6, 9, 4, 8, 5, 6, 9, 4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7, 4, 4, 6, 8, 7, 4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6, 3, 9, 7, 5, 6, 3, 9, 7, 5, 6]])

# %%
# matrix multipe
torch.matmul(a,a.T)
# Out:
# tensor([[222, 189, 203],
#         [189, 181, 172],
#         [203, 172, 200]])

# %%
a @ a.T
# Out:
# tensor([[222, 189, 203],
#         [189, 181, 172],
#         [203, 172, 200]])

# %%
a.matmul(a.T)
# Out:
# tensor([[222, 189, 203],
#         [189, 181, 172],
#         [203, 172, 200]])

# %%
# elementwise matrix multiple
torch.mul(a,a)
# Out:
# tensor([[16, 64, 25, 36, 81],
#         [16, 16, 36, 64, 49],
#         [ 9, 81, 49, 25, 36]])

# %%
a * a
# Out:
# tensor([[16, 64, 25, 36, 81],
#         [16, 16, 36, 64, 49],
#         [ 9, 81, 49, 25, 36]])

# %%
a.mul(a)
# Out:
# tensor([[16, 64, 25, 36, 81],
#         [16, 16, 36, 64, 49],
#         [ 9, 81, 49, 25, 36]])

# %%
print(torch.argmax(a))
print(torch.max(a).item())
print(torch.sum(a))
print(torch.abs(a))
# .item()
# Out:
# tensor(4)
# 9
# tensor(91)
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %%
a1 = torch.randint(3,10,(3,5))
a1
# Out:
# tensor([[5, 7, 8, 9, 8],
#         [6, 4, 3, 7, 4],
#         [3, 4, 6, 9, 8]])

# %%
a2 = torch.randint(3,10,(3,5))
a2
# Out:
# tensor([[6, 8, 8, 6, 5],
#         [8, 8, 8, 7, 3],
#         [5, 4, 5, 9, 5]])

# %%
torch.eq(a1,a2) # same dimensions
# Out:
# tensor([[False, False,  True, False, False],
#         [False, False, False,  True, False],
#         [False,  True, False,  True, False]])

# %%
torch.save(a,'weight.pt')

# %%
torch.load('/content/weight.pt')
# Out:
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %% [markdown]
# you can use numpy for generating random numbers and then turn them into torch tensor

# %%
a.device
# Out:
# device(type='cpu')

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# for RuntimeError search STACK OVERFLOW

# %%
# the CUDA tool is a development environment for creating high performance GPU accelerated aplications
# that for this you need an NVIDIA GPU on your machine
a = a.to('cuda')

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision import datasets, transforms
from torch import nn, optim
import cv2
from tqdm import tqdm

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("Device", device)
# Out:
# Device cuda

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])
# https://pytorch.org/vision/stable/transforms.html

# %%
# https://pytorch.org/vision/main/datasets.html
train_path = './mnist/train/'
test_path = './mnist/test/'
trainset = datasets.MNIST(train_path, download=True, train=True, transform=transform)
valset = datasets.MNIST(test_path, download=True, train=False, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist/train/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 101087351.21it/s]
# Extracting ./mnist/train/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist/train/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist/train/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 26985006.42it/s]
# Extracting ./mnist/train/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist/train/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist/train/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 29265314.80it/s]
# Extracting ./mnist/train/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist/train/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/train/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 5966341.61it/s]
# Extracting ./mnist/train/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist/train/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist/test/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 86697886.22it/s]
# Extracting ./mnist/test/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist/test/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist/test/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 20122208.28it/s]
# Extracting ./mnist/test/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist/test/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist/test/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 27240037.48it/s]
# Extracting ./mnist/test/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist/test/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/test/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 20223491.26it/s]
# Extracting ./mnist/test/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist/test/MNIST/raw

# %%
trainset
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./mnist/train/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )

# %%
for option in dir(trainset):
    if option[0] != '_':
        print(option)
# Out:
# class_to_idx
# classes
# data
# download
# extra_repr
# mirrors
# processed_folder
# raw_folder
# resources
# root
# target_transform
# targets
# test_data
# test_file
# test_labels
# train
# train_data
# train_labels
# training_file
# transform
# transforms

# %%
trainset.class_to_idx
# Out:
# {'0 - zero': 0,
#  '1 - one': 1,
#  '2 - two': 2,
#  '3 - three': 3,
#  '4 - four': 4,
#  '5 - five': 5,
#  '6 - six': 6,
#  '7 - seven': 7,
#  '8 - eight': 8,
#  '9 - nine': 9}

# %%
print(trainset.data.shape)
print(trainset.targets.shape)
print(valset.data.shape)
print(valset.targets.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([60000])
# torch.Size([10000, 28, 28])
# torch.Size([10000])

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=False)

# %%
for option in dir(trainloader):
    if option[0] != '_':
        print(option)
# Out:
# batch_sampler
# batch_size
# check_worker_number_rationality
# collate_fn
# dataset
# drop_last
# generator
# multiprocessing_context
# num_workers
# persistent_workers
# pin_memory
# pin_memory_device
# prefetch_factor
# sampler
# timeout
# worker_init_fn

# %%
dataiter = iter(trainloader)
images ,labels = next(dataiter)

print(images.shape)
print(labels.shape)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64])

# %%
num_of_images = 25
for index in range(1, num_of_images+1):
    plt.subplot(5,5, index)
    plt.axis('off')
    plt.imshow(images[index].numpy().squeeze(),cmap='gray')

# %%
input_size = 28 * 28
hidden_size = [256, 128]
output_size = 10

# %%
model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(input_size, hidden_size[0]),
    nn.ReLU(),
    nn.Linear(hidden_size[0],hidden_size[1]),
    nn.ReLU(),
    nn.Linear(hidden_size[1],output_size)
)

# %%
print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=256, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=256, out_features=128, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
class MyModel(nn.Module):
    def __init__(self, input_dim, hidden_dims, output_dim):
        super().__init__()
        self.flatten = nn.Flatten()
        self.layers = list()
        self.layers.append(nn.Linear(input_size,hidden_dims[0]))
        self.layers.append(nn.ReLU())
        for idx in range(len(hidden_dims)-1):
            self.layers.append(nn.Linear(hidden_dims[idx],hidden_size[idx+1]))
            self.layers.append(nn.ReLU())
        self.layers.append(nn.Linear(hidden_dims[-1],output_dim))

    def forward(self, X):
        x = self.flatten(X)
        for layer in self.layers:
            x = layer(x)

        return x

# %%
model1 = MyModel(input_size, hidden_size, output_size)

# %%
_ = model.to(device)

# %%
lr = 0.001
n_epochs = 10
val_per_epoch = 1
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

# %%
def accuracy(y_pred, y):
    """
    Calculating the accuracy of given batch.
    input(s):
    y_pred (ndarray): predicted logits or the output of the model.
    y (ndarray): labels
    """
    pred_idx = y_pred.max(1, keepdim=True)[1]
    correct = pred_idx.eq(y.view_as(pred_idx)).sum().item()
    return correct / len(y)

# %%
history = dict()
history['train_loss']= list()
history['train_acc']= list()
history['val_loss']= list()
history['val_acc']= list()
for epoch in range(n_epochs):
    running_loss = 0
    running_acc = 0

    model.train()
    for idx, (X, y) in enumerate(tqdm(trainloader)):
        optimizer.zero_grad()
        X, y = X.to(device), y.to(device)
        y_hat = model(X)
        loss = criterion(y_hat, y)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_acc += accuracy(y_hat, y)
    else:
        running_loss = running_loss/ len(trainloader)
        running_acc = running_acc / len(trainloader)
        history['train_loss'].append(running_loss)
        history['train_acc'].append(running_acc)
        print(f'Epoch {epoch+1}/{n_epochs} : training loss: {round(running_loss,3)}, training acc: {round(running_acc*100,2)}')



    if epoch% val_per_epoch == val_per_epoch-1:
        running_loss = 0
        running_acc = 0
        model.eval()
        with torch.no_grad():
            for idx, (X, y) in enumerate(tqdm(valloader)):
                X, y = X.to(device), y.to(device)
                y_hat = model(X)
                loss = criterion(y_hat, y)

                running_loss += loss.item()
                running_acc += accuracy(y_hat, y)
            else:
                running_loss = running_loss/ len(valloader)
                running_acc = running_acc / len(valloader)
                history['val_loss'].append(running_loss)
                history['val_acc'].append(running_acc)
                print(f'Epoch {epoch+1}/{n_epochs} : validation loss: {round(running_loss,3)}, validation acc: {round(running_acc*100,2)}')
# Out:
# 100%|██████████| 938/938 [00:17<00:00, 54.24it/s]
# Epoch 1/10 : training loss: 0.339, training acc: 89.7
# 100%|██████████| 157/157 [00:02<00:00, 76.49it/s]
# Epoch 1/10 : validation loss: 0.167, validation acc: 94.87
# 100%|██████████| 938/938 [00:14<00:00, 63.59it/s]
# Epoch 2/10 : training loss: 0.155, training acc: 95.21
# 100%|██████████| 157/157 [00:02<00:00, 72.65it/s]
# Epoch 2/10 : validation loss: 0.115, validation acc: 96.21
# 100%|██████████| 938/938 [00:14<00:00, 66.47it/s]
# Epoch 3/10 : training loss: 0.111, training acc: 96.59
# 100%|██████████| 157/157 [00:01<00:00, 78.75it/s]
# Epoch 3/10 : validation loss: 0.105, validation acc: 96.69
# 100%|██████████| 938/938 [00:14<00:00, 66.35it/s]
# Epoch 4/10 : training loss: 0.09, training acc: 97.2
# 100%|██████████| 157/157 [00:02<00:00, 78.04it/s]
# Epoch 4/10 : validation loss: 0.105, validation acc: 96.69
# 100%|██████████| 938/938 [00:14<00:00, 63.76it/s]
# Epoch 5/10 : training loss: 0.078, training acc: 97.52
# 100%|██████████| 157/157 [00:02<00:00, 72.40it/s]
# Epoch 5/10 : validation loss: 0.083, validation acc: 97.35
# 100%|██████████| 938/938 [00:14<00:00, 62.71it/s]
# Epoch 6/10 : training loss: 0.068, training acc: 97.82
# 100%|██████████| 157/157 [00:01<00:00, 78.61it/s]
# Epoch 6/10 : validation loss: 0.087, validation acc: 97.42
# 100%|██████████| 938/938 [00:14<00:00, 66.77it/s]
# Epoch 7/10 : training loss: 0.059, training acc: 98.12
# 100%|██████████| 157/157 [00:02<00:00, 67.52it/s]
# Epoch 7/10 : validation loss: 0.091, validation acc: 97.27
# 100%|██████████| 938/938 [00:14<00:00, 65.03it/s]
# Epoch 8/10 : training loss: 0.052, training acc: 98.35
# 100%|██████████| 157/157 [00:02<00:00, 78.22it/s]
# Epoch 8/10 : validation loss: 0.085, validation acc: 97.51
# 100%|██████████| 938/938 [00:13<00:00, 67.56it/s]
# Epoch 9/10 : training loss: 0.047, training acc: 98.47
# 100%|██████████| 157/157 [00:01<00:00, 79.02it/s]
# Epoch 9/10 : validation loss: 0.097, validation acc: 96.87
# 100%|██████████| 938/938 [00:13<00:00, 67.54it/s]
# Epoch 10/10 : training loss: 0.044, training acc: 98.5
# 100%|██████████| 157/157 [00:01<00:00, 78.65it/s]
# Epoch 10/10 : validation loss: 0.105, validation acc: 97.24

# %%
plt.title('train loss')
plt.plot(history['train_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
plt.title('val loss')
plt.plot(history['val_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
plt.title('train acc')
plt.plot(history['train_acc'])
plt.xlabel("epochs")
plt.ylabel("acc")
plt.show()

# %%
plt.title('val acc')
plt.plot(history['val_acc'])
plt.xlabel("epochs")
plt.ylabel("acc")
plt.show()

# %%
class CNN(nn.Module):
    def __init__(self, num_classes):
        super(CNN, self).__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(128, 256, kernel_size=3, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
        )

        self.fc_layers = nn.Sequential(
            nn.Linear(256 * 1* 1 , 512),
            nn.ReLU(),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.fc_layers(x)
        return x

# %%
model = CNN(10)

# %%
_ = model.to(device)

# %%
lr = 0.001
n_epochs = 10
val_per_epoch = 1
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

# %%
history = dict()
history['train_loss']= list()
history['train_acc']= list()
history['val_loss']= list()
history['val_acc']= list()
for epoch in range(n_epochs):
    running_loss = 0
    running_acc = 0

    model.train()
    for idx, (X, y) in enumerate(tqdm(trainloader)):
        optimizer.zero_grad()
        X, y = X.to(device), y.to(device)
        y_hat = model(X)
        loss = criterion(y_hat, y)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_acc += accuracy(y_hat, y)
    else:
        running_loss = running_loss/ len(trainloader)
        running_acc = running_acc / len(trainloader)
        history['train_loss'].append(running_loss)
        history['train_acc'].append(running_acc)
        print(f'Epoch {epoch+1}/{n_epochs} : training loss: {round(running_loss,3)}, training acc: {round(running_acc*100,2)}')



    if epoch% val_per_epoch == val_per_epoch-1:
        running_loss = 0
        running_acc = 0
        model.eval()
        with torch.no_grad():
            for idx, (X, y) in enumerate(tqdm(valloader)):
                X, y = X.to(device), y.to(device)
                y_hat = model(X)
                loss = criterion(y_hat, y)

                running_loss += loss.item()
                running_acc += accuracy(y_hat, y)
            else:
                running_loss = running_loss/ len(valloader)
                running_acc = running_acc / len(valloader)
                history['val_loss'].append(running_loss)
                history['val_acc'].append(running_acc)
                print(f'Epoch {epoch+1}/{n_epochs} : validation loss: {round(running_loss,3)}, validation acc: {round(running_acc*100,2)}')
# Out:
# 100%|██████████| 938/938 [00:21<00:00, 42.88it/s]
# Epoch 1/10 : training loss: 0.175, training acc: 94.57
# 100%|██████████| 157/157 [00:02<00:00, 59.59it/s]
# Epoch 1/10 : validation loss: 0.063, validation acc: 98.2
# 100%|██████████| 938/938 [00:17<00:00, 52.84it/s]
# Epoch 2/10 : training loss: 0.058, training acc: 98.24
# 100%|██████████| 157/157 [00:02<00:00, 70.69it/s]
# Epoch 2/10 : validation loss: 0.062, validation acc: 98.15
# 100%|██████████| 938/938 [00:17<00:00, 52.26it/s]
# Epoch 3/10 : training loss: 0.042, training acc: 98.7
# 100%|██████████| 157/157 [00:02<00:00, 74.05it/s]
# Epoch 3/10 : validation loss: 0.066, validation acc: 97.9
# 100%|██████████| 938/938 [00:17<00:00, 53.53it/s]
# Epoch 4/10 : training loss: 0.033, training acc: 98.97
# 100%|██████████| 157/157 [00:02<00:00, 68.33it/s]
# Epoch 4/10 : validation loss: 0.056, validation acc: 98.47
# 100%|██████████| 938/938 [00:18<00:00, 51.61it/s]
# Epoch 5/10 : training loss: 0.026, training acc: 99.19
# 100%|██████████| 157/157 [00:02<00:00, 69.82it/s]
# Epoch 5/10 : validation loss: 0.039, validation acc: 98.9
# 100%|██████████| 938/938 [00:18<00:00, 51.70it/s]
# Epoch 6/10 : training loss: 0.022, training acc: 99.32
# 100%|██████████| 157/157 [00:02<00:00, 66.78it/s]
# Epoch 6/10 : validation loss: 0.05, validation acc: 98.69
# 100%|██████████| 938/938 [00:17<00:00, 52.88it/s]
# Epoch 7/10 : training loss: 0.017, training acc: 99.49
# 100%|██████████| 157/157 [00:02<00:00, 70.30it/s]
# Epoch 7/10 : validation loss: 0.06, validation acc: 98.63
# 100%|██████████| 938/938 [00:18<00:00, 51.78it/s]
# Epoch 8/10 : training loss: 0.017, training acc: 99.47
# 100%|██████████| 157/157 [00:02<00:00, 71.02it/s]
# Epoch 8/10 : validation loss: 0.053, validation acc: 98.8
# 100%|██████████| 938/938 [00:17<00:00, 53.10it/s]
# Epoch 9/10 : training loss: 0.015, training acc: 99.54
# 100%|██████████| 157/157 [00:02<00:00, 60.72it/s]
# Epoch 9/10 : validation loss: 0.057, validation acc: 98.67
# 100%|██████████| 938/938 [00:17<00:00, 54.22it/s]
# Epoch 10/10 : training loss: 0.013, training acc: 99.6
# 100%|██████████| 157/157 [00:02<00:00, 72.29it/s]
# Epoch 10/10 : validation loss: 0.06, validation acc: 98.71

# %%
plt.title('train loss')
plt.plot(history['train_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
plt.title('val loss')
plt.plot(history['val_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
plt.title('train acc')
plt.plot(history['train_acc'])
plt.xlabel("epochs")
plt.ylabel("acc")
plt.show()

# %%
plt.title('val acc')
plt.plot(history['val_acc'])
plt.xlabel("epochs")
plt.ylabel("acc")
plt.show()
